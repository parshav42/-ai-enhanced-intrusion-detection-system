# %% [markdown]
# <a href="https://colab.research.google.com/github/parshav42/-ai-enhanced-intrusion-detection-system/blob/main/rag.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cp -r /content/drive/MyDrive/sugarcanepdf /content/

# %%
# !pip install pypdf

# %%
from pypdf import PdfReader

read = PdfReader("/content/sugarcanepdf/1203020427_removed.pdf")
with open('/content/sugarcanepdf/er.txt','w') as f:
    for index,page in enumerate(read.pages):
        text = page.extract_text()
        f.write(text)
