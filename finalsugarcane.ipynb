# %% [markdown]
# <a href="https://colab.research.google.com/github/parshav42/-ai-enhanced-intrusion-detection-system/blob/main/finalsugarcane.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !unzip -b /content/sugarcanedataset.zip -d /content/
# Out:
# Archive:  /content/sugarcanedataset.zip
#    creating: /content/sugarcanedataset/
#    creating: /content/sugarcanedataset/images/
#    creating: /content/sugarcanedataset/images/train/
#   inflating: /content/sugarcanedataset/images/train/brown45.jpg
#   inflating: /content/sugarcanedataset/images/train/brown1.jpg
#   inflating: /content/sugarcanedataset/images/train/brown2.jpg
#   inflating: /content/sugarcanedataset/images/train/brown3.jpg
#   inflating: /content/sugarcanedataset/images/train/brown4.jpg
#   inflating: /content/sugarcanedataset/images/train/brown5.jpg
#   inflating: /content/sugarcanedataset/images/train/brown6.jpg
#   inflating: /content/sugarcanedataset/images/train/brown7.jpg
#   inflating: /content/sugarcanedataset/images/train/brown8.jpg
#   inflating: /content/sugarcanedataset/images/train/brown9.jpg
#   inflating: /content/sugarcanedataset/images/train/brown10.jpg
#   inflating: /content/sugarcanedataset/images/train/brown11.jpg
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5
# !cd yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 32.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 5.3 MB/s eta 0:00:00
# ...

# %%
# !python /content/yolov5/train.py --img 640 --batch 16 --epoch 3 --data /content/sugarcanedataset/data.yaml --weights yolov5s.pt
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: WARNING W&B disabled due to login timeout.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# ...

# %%
from ultralytics import YOLO
import os

# The 'data' argument in model.train() expects the path to the YAML file, not a listdir result.
# dta = os.listdir("/content/sugarcanedataset/data.yaml")

model = YOLO("yolov5s.pt")

model.train(data = "/content/sugarcanedataset/data.yaml" , epochs =100 , imgsz =128)
# Out:
# PRO TIP 💡 Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
# Ultralytics 8.4.95 🚀 Python-3.12.13 torch-2.11.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/runs/detect/train-2/weights/best.pt")

results = model.predict(
    "/content/helthy20.jpg",
    save=True
)
# Out:
# image 1/1 /content/helthy20.jpg: 128x96 1 helthyleaf, 45.8ms
# Speed: 0.7ms preprocess, 45.8ms inference, 0.9ms postprocess per image at shape (1, 3, 128, 96)
# Results saved to /content/runs/detect/predict-4

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("/content/runs/detect/predict-3/image.jpg")

plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(735.5), np.float64(1103.5), np.float64(-0.5))
