# %% [markdown]
# <a href="https://colab.research.google.com/github/parshav42/-ai-enhanced-intrusion-detection-system/blob/main/indianhistryRAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymupdf
# !pip install sentence-transformers
# !pip install scikit-learn

# %%
import fitz

doc = fitz.open("/content/HISTORY-ENGLISH_removed.pdf")

text = ''

for page in doc:
    text += page.get_text()

print(text[:1000])

# %%
chunk_size =  600

chunks = []

for i in range(0 , len(text),chunk_size):
    chunks.append(text[i:i+chunk_size])


print(chunks[130])

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("all-MiniLM-L6-v2")

embeddings = model.encode(chunks)

print(embeddings.shape)

# %%
question = "historians mean ?"

# %%
question_embedding = model.encode(question)

# %%
from sklearn.metrics.pairwise import cosine_similarity

scores = cosine_similarity(
    [question_embedding],
    embeddings
)

best_index = scores.argmax()

print(chunks[best_index])

# %%
from huggingface_hub import login
login()
